# %% [markdown]
# <a href="https://colab.research.google.com/github/yuva0212/codesoft/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
x= np.random.randn(100)
y1=x*5+9
y2=-5*x
y3=np.random.randn(100) #Plot
plt.rcParams.update({
    'figure.figsize':(10,8),
    'figure.dpi':100
})
plt.scatter(x, y1, label=f"y1, Correlation = {np.round(np.corrcoef(x,y1)[0,1], 2)}")
plt.scatter(x, y2, label=f"y2 Correlation = {np.round(np.corrcoef(x,y2)[0,1], 2)}")
plt.scatter(x, y3, label=f"y3 Correlation = {np.round(np.corrcoef(x,y3)[0,1], 2)}")

# Plot


plt.title('Scatterplot and Correlations')
plt.legend()
plt.show()
